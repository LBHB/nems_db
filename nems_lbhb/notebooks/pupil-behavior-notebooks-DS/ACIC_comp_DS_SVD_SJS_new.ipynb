# %% [markdown]
# ## IC/A1 data per file: comparing datasets
#
# #### 2018/12 first created by DS
# #### UPDATE 2019/07/23 *This script is currently not used for any figure in the paper*
#
# In this notebook loads the csv files of each batch of data from Daniela's AC and IC tone in noise and tone vs noise data, Sean's IC tone vs noise ferret data, as well asd Stephen's A1 old data reanalized in Slee and David 2015. These data is then merged to information about STRF snr, target frequency, and more tuning info. The goal is to compare MI, gain, and offeset across these data sets.
#
# Batches:
# * **d_AC_307** DS, SU and MU, onBF and offBF
# * **d_AC_312** SVD, SU and MU, offBF
# * **d_AC_311** SVD, SU and MU, onBF
# * **d_IC_313** DS, SU and MU, onBF and offBF, pup and nopup
# * **d_IC_295** SJS, SU, onBF and offBF

# %%
import os
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %matplotlib inline
os.getcwd()

pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 60)

# %%
# AC SU+MU 307 DS' data (onBF and offBF together)
# run using beh_only_plot function in mod_per_state.py with state_list = ['st.fil0', 'st.fil'], 
# basemodel = '-ref-psthfr.s_stategain.S'
# loader = 'psth.fs20-ld-'
# fitter = '_jk.nf20-basic'
# get_model_results_per_state_model ---> returning df and saved on /auto/users/daniela/code/python_ACIC_proj/d_fil_307.csv 
# 12/18/18 DS
d_AC_307 = pd.read_csv('d_fil_307.csv')
d_AC_307 = d_AC_307.drop(['Unnamed: 0'], axis=1)
d_AC_307['experimenter'] = 'DS'
d_AC_307['area'] = 'AC'
d_AC_307['onBF'] = 'TBD'
d_AC_307['SU'] = False
d_AC_307.loc[d_AC_307['isolation']>=90.0, 'SU'] = True
d_AC_307['animal'] = d_AC_307['cellid'].map(lambda x: x[:3])
d_AC_307['task'] = 'TIN'

# %%
d_AC_307.head()
# Out:
#          cellid                                          modelname state_sig  \
# 0  BRT039c-24-1  psth.fs20-ld-st.fil0-ref-psthfr.s_stategain.S_...   st.fil0
# 1  BRT039c-24-1  psth.fs20-ld-st.fil0-ref-psthfr.s_stategain.S_...   st.fil0
# 2  BRT039c-24-1  psth.fs20-ld-st.fil0-ref-psthfr.s_stategain.S_...   st.fil0
# 3  BRT039c-24-1  psth.fs20-ld-st.fil0-ref-psthfr.s_stategain.S_...   st.fil0
# 4  BRT039c-24-1  psth.fs20-ld-st.fil0-ref-psthfr.s_stategain.S_...   st.fil0
#
#   state_chan        MI  isolation         r      r_se         d         g  \
# 0   baseline       NaN       95.0  0.527888  0.025994  0.479120  0.987548
# 1   ACTIVE_0  0.000929       95.0  0.527888  0.025994  0.010215  0.030706
# 2   ACTIVE_1  0.007505       95.0  0.527888  0.025994  0.006502 -0.047759
# 3  PASSIVE_1 -0.000139       95.0  0.527888  0.025994  0.001432 -0.065587
# 4   ACTIVE_2 -0.009450       95.0  0.527888  0.025994  0.009505  0.068927
#
#   state_chan_alt experimenter area onBF    SU animal task
# 0       baseline           DS   AC  TBD  True    BRT  TIN
# 1       ACTIVE_0           DS   AC  TBD  True    BRT  TIN
# 2       ACTIVE_1           DS   AC  TBD  True    BRT  TIN
# 3      PASSIVE_1           DS   AC  TBD  True    BRT  TIN
# 4       ACTIVE_2           DS   AC  TBD  True    BRT  TIN

# %%
# AC 311 SVD's data (onBF only)
# run using beh_only_plot function in mod_per_state.py with state_list = ['st.fil0', 'st.fil'], 
# basemodel = '-ref-psthfr.s_stategain.S'
# loader = 'psth.fs20-ld-'
# fitter = '_jk.nf20-basic'
# get_model_results_per_state_model ---> returning df and saved on /auto/users/daniela/code/python_ACIC_proj/d_fil_311.csv 
# 12/18/18 DS
d_AC_311 = pd.read_csv('d_fil_311.csv')
d_AC_311 = d_AC_311.drop(['Unnamed: 0'], axis=1)
d_AC_311['onBF'] = True
d_AC_311['experimenter'] = 'SVD'
d_AC_311['area'] = 'AC'
d_AC_311['SU'] = False
d_AC_311['animal'] = d_AC_311['cellid'].map(lambda x: x[:3])
d_AC_311['task'] = 'TvN'
d_AC_311.loc[d_AC_311['isolation']>=90.0, 'SU'] = True

# %%
d_AC_311.head()
# Out:
#        cellid                                          modelname state_sig  \
# 0  min040c-b1  psth.fs20-ld-st.fil0-ref-psthfr.s_stategain.S_...   st.fil0
# 1  min040c-b1  psth.fs20-ld-st.fil0-ref-psthfr.s_stategain.S_...   st.fil0
# 2  min040c-b1  psth.fs20-ld-st.fil0-ref-psthfr.s_stategain.S_...   st.fil0
# 3  min025b-a1  psth.fs20-ld-st.fil0-ref-psthfr.s_stategain.S_...   st.fil0
# 4  min025b-a1  psth.fs20-ld-st.fil0-ref-psthfr.s_stategain.S_...   st.fil0
#
#   state_chan        MI  isolation         r      r_se         d         g  \
# 0   baseline       NaN       89.3  0.570772  0.012738  0.314420  1.017320
# 1   ACTIVE_1  0.086269       89.3  0.570772  0.012738  0.009095 -0.012912
# 2  PASSIVE_1 -0.000187       89.3  0.570772  0.012738 -0.002934 -0.048724
# 3   baseline       NaN       97.1  0.668615  0.013436  0.550929  1.014233
# 4   ACTIVE_1 -0.003519       97.1  0.668615  0.013436  0.007092 -0.042009
#
#   state_chan_alt  onBF experimenter area     SU animal task
# 0       baseline  True          SVD   AC  False    min  TvN
# 1       ACTIVE_1  True          SVD   AC  False    min  TvN
# 2      PASSIVE_1  True          SVD   AC  False    min  TvN
# 3       baseline  True          SVD   AC   True    min  TvN
# 4       ACTIVE_1  True          SVD   AC   True    min  TvN

# %%
# AC 312 SVD's data offBF only
d_AC_312 = pd.read_csv('d_fil_312.csv')
d_AC_312 = d_AC_312.drop(['Unnamed: 0'], axis=1)
d_AC_312['onBF'] = False
d_AC_312['experimenter'] = 'SVD'
d_AC_312['area'] = 'AC'
d_AC_312['SU'] = False
d_AC_312.loc[d_AC_312['isolation']>=90.0, 'SU'] = True
d_AC_312['animal'] = d_AC_312['cellid'].map(lambda x: x[:3])
d_AC_312['task'] = 'TvN'

# %%
d_AC_312.head()
# Out:
#        cellid                                          modelname state_sig  \
# 0  oni015b-a1  psth.fs20-ld-st.fil0-ref-psthfr.s_stategain.S_...   st.fil0
# 1  oni015b-a1  psth.fs20-ld-st.fil0-ref-psthfr.s_stategain.S_...   st.fil0
# 2  mar015a-d1  psth.fs20-ld-st.fil0-ref-psthfr.s_stategain.S_...   st.fil0
# 3  mar015a-d1  psth.fs20-ld-st.fil0-ref-psthfr.s_stategain.S_...   st.fil0
# 4  mar015a-d1  psth.fs20-ld-st.fil0-ref-psthfr.s_stategain.S_...   st.fil0
#
#   state_chan        MI  isolation        r      r_se         d         g  \
# 0   baseline       NaN       82.6  0.44308  0.025830  0.299212  1.011672
# 1   ACTIVE_1  0.001298       82.6  0.44308  0.025830 -0.003698  0.012004
# 2   baseline       NaN       98.9  0.42443  0.017614  0.067215  1.081200
# 3   ACTIVE_1 -0.004457       98.9  0.42443  0.017614  0.009422 -0.047524
# 4  PASSIVE_1 -0.000265       98.9  0.42443  0.017614 -0.000971 -0.011728
#
#   state_chan_alt   onBF experimenter area     SU animal task
# 0       baseline  False          SVD   AC  False    oni  TvN
# 1       ACTIVE_1  False          SVD   AC  False    oni  TvN
# 2       baseline  False          SVD   AC   True    mar  TvN
# 3       ACTIVE_1  False          SVD   AC   True    mar  TvN
# 4      PASSIVE_1  False          SVD   AC   True    mar  TvN

# %%
# IC SU only 305 DS' data onBF+offBF (pupil+nopupil dataset)
d_IC_305 = pd.read_csv('d_fil_305.csv') # run with stategain model on October 31st
d_IC_305 = d_IC_305.drop(['Unnamed: 0'], axis=1)
d_IC_305['onBF'] = 'TBD'
d_IC_305['experimenter'] = 'DS'
d_IC_305['area'] = 'IC'
d_IC_305['animal'] = d_IC_305['cellid'].map(lambda x: x[:3])
d_IC_305['task'] = 'TIN'
d_IC_305.loc[d_IC_305['animal']=='ley', 'task'] = 'TvN'
d_IC_305['SU'] = True

# %%
d_IC_305.head()
# Out:
#          cellid                                          modelname state_sig  \
# 0  ley046f-30-1  psth.fs20-ld-st.fil0-ref-psthfr.s_stategain.S_...   st.fil0
# 1  ley046f-30-1  psth.fs20-ld-st.fil0-ref-psthfr.s_stategain.S_...   st.fil0
# 2  ley046f-30-1  psth.fs20-ld-st.fil0-ref-psthfr.s_stategain.S_...   st.fil0
# 3  ley046f-01-1  psth.fs20-ld-st.fil0-ref-psthfr.s_stategain.S_...   st.fil0
# 4  ley046f-01-1  psth.fs20-ld-st.fil0-ref-psthfr.s_stategain.S_...   st.fil0
#
#   state_chan        MI  isolation         r      r_se         d         g  \
# 0   baseline       NaN       95.0  0.324489  0.019250  2.948240  0.986153
# 1   ACTIVE_1 -0.000129       95.0  0.324489  0.019250  0.005885  0.028052
# 2  PASSIVE_1 -0.000057       95.0  0.324489  0.019250 -0.015325 -0.031916
# 3   baseline       NaN       95.0  0.534155  0.012018  2.248138  1.010021
# 4   ACTIVE_1 -0.000309       95.0  0.534155  0.012018  0.004542 -0.034270
#
#   state_chan_alt onBF experimenter area animal task    SU
# 0       baseline  TBD           DS   IC    ley  TvN  True
# 1       ACTIVE_1  TBD           DS   IC    ley  TvN  True
# 2      PASSIVE_1  TBD           DS   IC    ley  TvN  True
# 3       baseline  TBD           DS   IC    ley  TvN  True
# 4       ACTIVE_1  TBD           DS   IC    ley  TvN  True

# %%
# IC SU+MU 309 DS' data onBF+offBF (pupil only dataset)
d_IC_309 = pd.read_csv('d_fil_309.csv') # run with stategain model on October 31st
d_IC_309 = d_IC_309.drop(['Unnamed: 0'], axis=1)
d_IC_309['onBF'] = 'TBD'
d_IC_309['experimenter'] = 'DS'
d_IC_309['area'] = 'IC'
d_IC_309['animal'] = d_IC_309['cellid'].map(lambda x: x[:3])
d_IC_309['task'] = 'TIN'
d_IC_309.loc[d_IC_309['animal']=='ley', 'task'] = 'TvN'
d_IC_309['SU'] = False
d_IC_309.loc[d_IC_309['isolation']>=90.0, 'SU'] = True

# %%
d_IC_309.head()
# Out:
#          cellid                                          modelname state_sig  \
# 0  ley046g-59-1  psth.fs20-ld-st.fil0-ref-psthfr.s_stategain.S_...   st.fil0
# 1  ley046g-59-1  psth.fs20-ld-st.fil0-ref-psthfr.s_stategain.S_...   st.fil0
# 2  ley046g-59-1  psth.fs20-ld-st.fil0-ref-psthfr.s_stategain.S_...   st.fil0
# 3  ley046g-59-1  psth.fs20-ld-st.fil0-ref-psthfr.s_stategain.S_...   st.fil0
# 4  ley046g-59-1  psth.fs20-ld-st.fil0-ref-psthfr.s_stategain.S_...   st.fil0
#
#   state_chan        MI  isolation         r      r_se         d         g  \
# 0   baseline       NaN    76.5731  0.330774  0.028566  4.264236  1.030489
# 1   ACTIVE_1 -0.001771    76.5731  0.330774  0.028566 -0.033870 -0.140662
# 2  PASSIVE_1 -0.000261    76.5731  0.330774  0.028566  0.019135  0.109547
# 3  PASSIVE_2 -0.069197    76.5731  0.330774  0.028566  0.018223 -0.035924
# 4   ACTIVE_2 -0.070740    76.5731  0.330774  0.028566 -0.003952  0.035454
#
#   state_chan_alt onBF experimenter area animal task     SU
# 0       baseline  TBD           DS   IC    ley  TvN  False
# 1       ACTIVE_1  TBD           DS   IC    ley  TvN  False
# 2      PASSIVE_1  TBD           DS   IC    ley  TvN  False
# 3      PASSIVE_2  TBD           DS   IC    ley  TvN  False
# 4       ACTIVE_2  TBD           DS   IC    ley  TvN  False

# %%
# IC SU+MU 313 DS' data onBF+offBF (pupil+nopupil dataset)
d_IC_313 = pd.read_csv('d_fil_313.csv') # run with stategain model on December 31st
d_IC_313 = d_IC_313.drop(['Unnamed: 0'], axis=1)
d_IC_313['onBF'] = 'TBD'
d_IC_313['experimenter'] = 'DS'
d_IC_313['area'] = 'IC'
d_IC_313['animal'] = d_IC_313['cellid'].map(lambda x: x[:3])
d_IC_313['task'] = 'TIN'
d_IC_313.loc[d_IC_313['animal']=='ley', 'task'] = 'TvN'
d_IC_313['SU'] = False
d_IC_313.loc[d_IC_313['isolation']>=90.0, 'SU'] = True

# %%
d_IC_313.tail()
# Out:
#          cellid                                          modelname state_sig  \
# 945  bbl021h-a1  psth.fs20-ld-st.fil-ref-psthfr.s_stategain.S_j...    st.fil
# 946  bbl021h-a1  psth.fs20-ld-st.fil-ref-psthfr.s_stategain.S_j...    st.fil
# 947  bbl021h-a1  psth.fs20-ld-st.fil-ref-psthfr.s_stategain.S_j...    st.fil
# 948  bbl019f-a1  psth.fs20-ld-st.fil-ref-psthfr.s_stategain.S_j...    st.fil
# 949  bbl019f-a1  psth.fs20-ld-st.fil-ref-psthfr.s_stategain.S_j...    st.fil
#
#     state_chan        MI  isolation         r      r_se         d         g  \
# 945   ACTIVE_1  0.122172       90.0  0.798116  0.010927  0.071092  0.287892
# 946   ACTIVE_2  0.153066       90.0  0.798116  0.010927  0.069127  0.448549
# 947  PASSIVE_1  0.122949       90.0  0.798116  0.010927  0.115533  0.196785
# 948   baseline       NaN       81.7  0.799928  0.010812  1.424169  1.000442
# 949   ACTIVE_0 -0.066071       81.7  0.799928  0.010812 -0.242964 -0.002124
#
#     state_chan_alt onBF experimenter area animal task     SU
# 945       ACTIVE_1  TBD           DS   IC    bbl  TIN   True
# 946       ACTIVE_2  TBD           DS   IC    bbl  TIN   True
# 947      PASSIVE_1  TBD           DS   IC    bbl  TIN   True
# 948       baseline  TBD           DS   IC    bbl  TIN  False
# 949       ACTIVE_0  TBD           DS   IC    bbl  TIN  False

# %%
# IC SU 295 Sean's data 
d_IC_295 = pd.read_csv('d_295_IC_old.csv')
d_IC_295 = d_IC_295.drop(['Unnamed: 0'], axis=1)
d_IC_295['onBF'] = 'TBD'
d_IC_295['experimenter'] = 'SJS'
d_IC_295['animal'] = d_IC_295['cellid'].map(lambda x: x[:3])
d_IC_295['area'] = 'IC'
d_IC_295['task'] = 'TvN'
d_IC_295['SU'] = True

# %%
d_IC_295.head()
# Out:
#        cellid                                          modelname state_sig  \
# 0  mgc015b-a1  psth.fs20-ld-st.fil0-ref-psthfr.s_stategain.S_...   st.fil0
# 1  mgc015b-a1  psth.fs20-ld-st.fil0-ref-psthfr.s_stategain.S_...   st.fil0
# 2  btn118a-b1  psth.fs20-ld-st.fil0-ref-psthfr.s_stategain.S_...   st.fil0
# 3  btn118a-b1  psth.fs20-ld-st.fil0-ref-psthfr.s_stategain.S_...   st.fil0
# 4  btn112e-b1  psth.fs20-ld-st.fil0-ref-psthfr.s_stategain.S_...   st.fil0
#
#   state_chan        MI         r      r_se         d         g state_chan_alt  \
# 0   baseline       NaN  0.749101  0.010687  0.977096  0.992315       baseline
# 1   ACTIVE_1  0.000119  0.749101  0.010687 -0.014628  0.012263       ACTIVE_1
# 2   baseline       NaN  0.908095  0.006147  0.804864  1.002105       baseline
# 3   ACTIVE_0  0.000020  0.908095  0.006147  0.002751 -0.003194       ACTIVE_0
# 4   baseline       NaN  0.904820  0.006381  5.080505  1.004410       baseline
#
#   onBF experimenter animal area task    SU
# 0  TBD          SJS    mgc   IC  TvN  True
# 1  TBD          SJS    mgc   IC  TvN  True
# 2  TBD          SJS    btn   IC  TvN  True
# 3  TBD          SJS    btn   IC  TvN  True
# 4  TBD          SJS    btn   IC  TvN  True

# %%
# concat dataframes 
# d_AC_307 DS, SU and MU, onBF and offBF
# d_AC_312 SVD, SU and MU, offBF
# d_AC_311 SVD, SU and MU, onBF
# d_IC_313 DS, SU and MU, onBF and offBF, pup and nopup
# d_IC_295 SJS, SU, onBF and offBF
d_all = pd.concat([d_AC_307, d_AC_312, d_AC_311, d_IC_313, d_IC_295], sort=False)

# %%
# add columns with R2
d_all['R2'] = d_all['r']**2 * np.sign(d_all['r'])

# %%
d_all.head()
# Out:
#          cellid                                          modelname state_sig  \
# 0  BRT039c-24-1  psth.fs20-ld-st.fil0-ref-psthfr.s_stategain.S_...   st.fil0
# 1  BRT039c-24-1  psth.fs20-ld-st.fil0-ref-psthfr.s_stategain.S_...   st.fil0
# 2  BRT039c-24-1  psth.fs20-ld-st.fil0-ref-psthfr.s_stategain.S_...   st.fil0
# 3  BRT039c-24-1  psth.fs20-ld-st.fil0-ref-psthfr.s_stategain.S_...   st.fil0
# 4  BRT039c-24-1  psth.fs20-ld-st.fil0-ref-psthfr.s_stategain.S_...   st.fil0
#
#   state_chan        MI  isolation         r      r_se         d         g  \
# 0   baseline       NaN       95.0  0.527888  0.025994  0.479120  0.987548
# 1   ACTIVE_0  0.000929       95.0  0.527888  0.025994  0.010215  0.030706
# 2   ACTIVE_1  0.007505       95.0  0.527888  0.025994  0.006502 -0.047759
# 3  PASSIVE_1 -0.000139       95.0  0.527888  0.025994  0.001432 -0.065587
# 4   ACTIVE_2 -0.009450       95.0  0.527888  0.025994  0.009505  0.068927
#
#   state_chan_alt experimenter area onBF    SU animal task        R2
# 0       baseline           DS   AC  TBD  True    BRT  TIN  0.278666
# 1       ACTIVE_0           DS   AC  TBD  True    BRT  TIN  0.278666
# 2       ACTIVE_1           DS   AC  TBD  True    BRT  TIN  0.278666
# 3      PASSIVE_1           DS   AC  TBD  True    BRT  TIN  0.278666
# 4       ACTIVE_2           DS   AC  TBD  True    BRT  TIN  0.278666

# %%
#d_all[d_all['cellid']=='BRT016f-a1']

# %%
# generated by running get_ptd_tuning in MATLAB and then running struct2csv(cellframe, 'tuning_info_batch_295.csv')
# IC data Sean's SU only
d_295_strf = pd.read_csv('tuning_info_batch_295.csv')
d_295_strf = d_295_strf.drop(['Unnamed: 24'], axis=1)

# %%
d_295_strf.head()
# Out:
#        cellid  bestsnr  bestbf  PASSIVE_0_snr  PASSIVE_0_bf        PASSIVE_0  \
# 0  btn006a-b1  1.90130    9801       1.901300          9801  btn006a01_p_TOR
# 1  btn009b-b1  0.29041   13337       0.290410         13337  btn009b02_p_TOR
# 2  btn011a-b1  0.66152     639       0.661520           639  btn011a02_p_TOR
# 3  btn011c-b1  0.72878     441       0.728780           441  btn011c01_p_TOR
# 4  btn012c-a1  1.66290   10810       0.058383         24184  btn012c01_p_TOR
#
#    ACTIVE_1_snr  ACTIVE_1_bf         ACTIVE_1  ACTIVE_1_tf  ACTIVE_1_tardist  \
# 0       0.49429       9464.0  btn006a02_a_PTD      10000.0         -0.028999
# 1       0.16060       2858.0  btn009b03_a_PTD      14000.0         -0.069993
# 2       0.38448       7407.0  btn011a03_a_PTD        650.0         -0.024624
# 3       0.55081        457.0  btn011c02_a_PTD        500.0         -0.181150
# 4       1.15170      10438.0  btn012c02_a_PTD       8000.0          0.434290
#
#    PASSIVE_1_snr  PASSIVE_1_bf        PASSIVE_1  ACTIVE_2_snr  ACTIVE_2_bf  \
# 0            NaN           NaN              NaN           NaN          NaN
# 1            NaN           NaN              NaN           NaN          NaN
# 2            NaN           NaN              NaN           NaN          NaN
# 3            NaN           NaN              NaN           NaN          NaN
# 4         1.6016       18277.0  btn012c04_p_PTD        1.6629      10810.0
#
#           ACTIVE_2  ACTIVE_2_tf  ACTIVE_2_tardist  ACTIVE_0_snr  ACTIVE_0_bf  \
# 0              NaN          NaN               NaN           NaN          NaN
# 1              NaN          NaN               NaN           NaN          NaN
# 2              NaN          NaN               NaN           NaN          NaN
# 3              NaN          NaN               NaN           NaN          NaN
# 4  btn012c05_a_PTD      10500.0          0.041977           NaN          NaN
#
#   ACTIVE_0  ACTIVE_0_tf  ACTIVE_0_tardist
# 0      NaN          NaN               NaN
# 1      NaN          NaN               NaN
# 2      NaN          NaN               NaN
# 3      NaN          NaN               NaN
# 4      NaN          NaN               NaN

# %%
# generated by running get_ptd_tuning in MATLAB and then running struct2csv(cellframe, 'tuning_info_batch_307.csv')
# AC data DS' SU+MU
d_307_strf = pd.read_csv('tuning_info_batch_307.csv')
d_307_strf = d_307_strf.drop(['Unnamed: 43'], axis=1)

# %%
d_307_strf.head()
# Out:
#          cellid  bestsnr  bestbf  PASSIVE_0_snr  PASSIVE_0_bf  \
# 0  BRT026c-02-1  0.46910   29836       0.206060         25938
# 1  BRT026c-02-2  0.19124    1576      -0.000456         18277
# 2  BRT026c-05-1  0.10056    5183       0.088553          2399
# 3  BRT026c-05-2  0.80741   20300       0.209490          1576
# 4  BRT026c-07-1  4.60680   21024       1.862900         21773
#
#            PASSIVE_0  ACTIVE_1_snr  ACTIVE_1_bf           ACTIVE_1  \
# 0  BRT026c04_p_PTD.m      0.307710      25938.0  BRT026c08_a_PTD.m
# 1  BRT026c09_p_PTD.m      0.015065       1278.0  BRT026c11_a_PTD.m
# 2  BRT026c09_p_PTD.m      0.056634      12435.0  BRT026c11_a_PTD.m
# 3  BRT026c04_p_PTD.m      0.694700      20300.0  BRT026c08_a_PTD.m
# 4  BRT026c04_p_PTD.m      3.525100      21024.0  BRT026c08_a_PTD.m
#
#    ACTIVE_1_tf  ACTIVE_1_tardist  PASSIVE_1_snr  PASSIVE_1_bf  \
# 0      14000.0           1.09160        0.22611        2485.0
# 1      14000.0          -3.15110            NaN           NaN
# 2      14000.0          -1.43360            NaN           NaN
# 3      14000.0           0.53605        0.37554       29836.0
# 4      14000.0           0.58661        1.43180       20300.0
#
#            PASSIVE_1  ACTIVE_2_snr  ACTIVE_2_bf           ACTIVE_2  \
# 0  BRT026c09_p_PTD.m      0.469100      29836.0  BRT026c11_a_PTD.m
# 1                NaN      0.191240       1576.0  BRT026c12_a_PTD.m
# 2                NaN      0.023143       5962.0  BRT026c12_a_PTD.m
# 3  BRT026c09_p_PTD.m      0.807410      20300.0  BRT026c11_a_PTD.m
# 4  BRT026c09_p_PTD.m      4.606800      21024.0  BRT026c11_a_PTD.m
#
#    ACTIVE_2_tf  ACTIVE_2_tardist  ACTIVE_3_snr  ACTIVE_3_bf  \
# 0      14000.0           1.09160       0.20944       3066.0
# 1      14000.0          -3.15110           NaN          NaN
# 2      14000.0          -1.43360           NaN          NaN
# 3      14000.0           0.53605       0.35755      19602.0
# 4      14000.0           0.58661       2.72040      21024.0
#
#             ACTIVE_3  ACTIVE_3_tf  ACTIVE_3_tardist  ACTIVE_0_snr  \
# 0  BRT026c12_a_PTD.m      14000.0           1.09160           NaN
# 1                NaN          NaN               NaN       0.11800
# 2                NaN          NaN               NaN       0.10056
# 3  BRT026c12_a_PTD.m      14000.0           0.53605           NaN
# 4  BRT026c12_a_PTD.m      14000.0           0.58661           NaN
#
#    ACTIVE_0_bf           ACTIVE_0  ACTIVE_0_tf  ACTIVE_0_tardist  \
# 0          NaN                NaN          NaN               NaN
# 1      14814.0  BRT026c08_a_PTD.m      14000.0           -3.1511
# 2       5183.0  BRT026c08_a_PTD.m      14000.0           -1.4336
# 3          NaN                NaN          NaN               NaN
# 4          NaN                NaN          NaN               NaN
#
#    PASSIVE_2_snr  PASSIVE_2_bf PASSIVE_2  PASSIVE_3_snr  PASSIVE_3_bf  \
# 0            NaN           NaN       NaN            NaN           NaN
# 1            NaN           NaN       NaN            NaN           NaN
# 2            NaN           NaN       NaN            NaN           NaN
# 3            NaN           NaN       NaN            NaN           NaN
# 4            NaN           NaN       NaN            NaN           NaN
#
#   PASSIVE_3  ACTIVE_4_snr  ACTIVE_4_bf ACTIVE_4  ACTIVE_4_tf  \
# 0       NaN           NaN          NaN      NaN          NaN
# 1       NaN           NaN          NaN      NaN          NaN
# 2       NaN           NaN          NaN      NaN          NaN
# 3       NaN           NaN          NaN      NaN          NaN
# 4       NaN           NaN          NaN      NaN          NaN
#
#    ACTIVE_4_tardist  PASSIVE_4_snr  PASSIVE_4_bf PASSIVE_4
# 0               NaN            NaN           NaN       NaN
# 1               NaN            NaN           NaN       NaN
# 2               NaN            NaN           NaN       NaN
# 3               NaN            NaN           NaN       NaN
# 4               NaN            NaN           NaN       NaN

# %%
# generated by running get_ptd_tuning in MATLAB and then running struct2csv(cellframe, 'tuning_info_batch_309.csv')
# IC data DS' SU (pupil+nopupil dataset)
d_305_strf = pd.read_csv('tuning_info_batch_305.csv')
d_305_strf = d_305_strf.drop(['Unnamed: 43'], axis=1)

# %%
d_305_strf.head()
# Out:
#        cellid   bestsnr  bestbf  PASSIVE_0_snr  PASSIVE_0_bf        PASSIVE_0  \
# 0  BRT005c-a1 -0.069176    4569      -0.180440           540  BRT005c04_p_PTD
# 1  BRT006d-a1 -0.002328     486      -0.042368          2191  BRT006d04_p_PTD
# 2  BRT006d-a2  0.126090    1014       0.099402           469  BRT006d04_p_PTD
# 3  BRT007c-a1  0.881940     441       0.242300           473  BRT007c04_p_PTD
# 4  BRT007c-a3  0.592250     490       0.592250           490  BRT007c11_p_PTD
#
#    ACTIVE_1_snr  ACTIVE_1_bf         ACTIVE_1  ACTIVE_1_tf  ACTIVE_1_tardist  \
# 0     -0.069176       4569.0  BRT005c06_a_PTD       1000.0          2.191900
# 1     -0.002328        486.0  BRT006d05_a_PTD       2000.0         -2.041000
# 2     -0.020204       2799.0  BRT006d05_a_PTD       2000.0         -0.979940
# 3      0.278370        457.0  BRT007c05_a_PTD        500.0         -0.181150
# 4      0.368120        720.0  BRT007c12_a_PTD        500.0         -0.029146
#
#    PASSIVE_1_snr  PASSIVE_1_bf        PASSIVE_1  ACTIVE_2_snr  ACTIVE_2_bf  \
# 0      -0.185110        2703.0  BRT005c07_p_PTD      -0.19708       3576.0
# 1      -0.089563        5838.0  BRT006d06_p_PTD      -0.11694        715.0
# 2      -0.004029        3334.0  BRT006d06_p_PTD       0.12609       1014.0
# 3       0.603540         473.0  BRT007c06_p_PTD       0.67072        457.0
# 4            NaN           NaN              NaN           NaN          NaN
#
#           ACTIVE_2  ACTIVE_2_tf  ACTIVE_2_tardist  PASSIVE_2_snr  \
# 0  BRT005c08_a_PTD       1000.0           2.19190            NaN
# 1  BRT006d07_a_PTD       2000.0          -2.04100            NaN
# 2  BRT006d07_a_PTD       2000.0          -0.97994            NaN
# 3  BRT007c07_a_PTD        500.0          -0.18115        0.34821
# 4              NaN          NaN               NaN            NaN
#
#    PASSIVE_2_bf        PASSIVE_2  ACTIVE_3_snr  ACTIVE_3_bf         ACTIVE_3  \
# 0           NaN              NaN           NaN          NaN              NaN
# 1           NaN              NaN           NaN          NaN              NaN
# 2           NaN              NaN           NaN          NaN              NaN
# 3         411.0  BRT007c09_p_PTD       0.86043        473.0  BRT007c10_a_PTD
# 4           NaN              NaN           NaN          NaN              NaN
#
#    ACTIVE_3_tf  ACTIVE_3_tardist  PASSIVE_3_snr  PASSIVE_3_bf  \
# 0          NaN               NaN            NaN           NaN
# 1          NaN               NaN            NaN           NaN
# 2          NaN               NaN            NaN           NaN
# 3        500.0          -0.18115        0.87701         473.0
# 4          NaN               NaN            NaN           NaN
#
#          PASSIVE_3  ACTIVE_4_snr  ACTIVE_4_bf         ACTIVE_4  ACTIVE_4_tf  \
# 0              NaN           NaN          NaN              NaN          NaN
# 1              NaN           NaN          NaN              NaN          NaN
# 2              NaN           NaN          NaN              NaN          NaN
# 3  BRT007c11_p_PTD       0.88194        441.0  BRT007c12_a_PTD        500.0
# 4              NaN           NaN          NaN              NaN          NaN
#
#    ACTIVE_4_tardist  PASSIVE_4_snr  PASSIVE_4_bf PASSIVE_4  ACTIVE_0_snr  \
# 0               NaN            NaN           NaN       NaN           NaN
# 1               NaN            NaN           NaN       NaN           NaN
# 2               NaN            NaN           NaN       NaN           NaN
# 3          -0.18115            NaN           NaN       NaN           NaN
# 4               NaN            NaN           NaN       NaN           NaN
#
#    ACTIVE_0_bf ACTIVE_0  ACTIVE_0_tf  ACTIVE_0_tardist
# 0          NaN      NaN          NaN               NaN
# 1          NaN      NaN          NaN               NaN
# 2          NaN      NaN          NaN               NaN
# 3          NaN      NaN          NaN               NaN
# 4          NaN      NaN          NaN               NaN

# %%
# generated by running get_ptd_tuning in MATLAB and then running struct2csv(cellframe, 'tuning_info_batch_309.csv')
# IC data DS' SU+MU (pupil+nopupil dataset)
d_313_strf = pd.read_csv('tuning_info_batch_313.csv')
d_313_strf = d_313_strf.drop(['Unnamed: 48'], axis=1)

# %%
d_313_strf.head()
# Out:
#        cellid   bestsnr  bestbf  PASSIVE_0_snr  PASSIVE_0_bf        PASSIVE_0  \
# 0  BRT005c-a1 -0.069176    4569      -0.180440           540  BRT005c04_p_PTD
# 1  BRT006d-a1 -0.002328     486      -0.042368          2191  BRT006d04_p_PTD
# 2  BRT006d-a2  0.126090    1014       0.099402           469  BRT006d04_p_PTD
# 3  BRT007c-a1  0.881940     441       0.242300           473  BRT007c04_p_PTD
# 4  BRT007c-a3  0.592250     490       0.592250           490  BRT007c11_p_PTD
#
#    ACTIVE_1_snr  ACTIVE_1_bf         ACTIVE_1  ACTIVE_1_tf  ACTIVE_1_tardist  \
# 0     -0.069176       4569.0  BRT005c06_a_PTD       1000.0          2.191900
# 1     -0.002328        486.0  BRT006d05_a_PTD       2000.0         -2.041000
# 2     -0.020204       2799.0  BRT006d05_a_PTD       2000.0         -0.979940
# 3      0.278370        457.0  BRT007c05_a_PTD        500.0         -0.181150
# 4      0.368120        720.0  BRT007c12_a_PTD        500.0         -0.029146
#
#    PASSIVE_1_snr  PASSIVE_1_bf        PASSIVE_1  ACTIVE_2_snr  ACTIVE_2_bf  \
# 0      -0.185110        2703.0  BRT005c07_p_PTD      -0.19708       3576.0
# 1      -0.089563        5838.0  BRT006d06_p_PTD      -0.11694        715.0
# 2      -0.004029        3334.0  BRT006d06_p_PTD       0.12609       1014.0
# 3       0.603540         473.0  BRT007c06_p_PTD       0.67072        457.0
# 4            NaN           NaN              NaN           NaN          NaN
#
#           ACTIVE_2  ACTIVE_2_tf  ACTIVE_2_tardist  ACTIVE_3_snr  ACTIVE_3_bf  \
# 0  BRT005c08_a_PTD       1000.0           2.19190      -0.18360       4732.0
# 1  BRT006d07_a_PTD       2000.0          -2.04100           NaN          NaN
# 2  BRT006d07_a_PTD       2000.0          -0.97994           NaN          NaN
# 3  BRT007c07_a_PTD        500.0          -0.18115       0.86043        473.0
# 4              NaN          NaN               NaN           NaN          NaN
#
#           ACTIVE_3  ACTIVE_3_tf  ACTIVE_3_tardist  PASSIVE_2_snr  \
# 0  BRT005c09_a_PTD       1000.0           2.19190       -0.13696
# 1              NaN          NaN               NaN            NaN
# 2              NaN          NaN               NaN            NaN
# 3  BRT007c10_a_PTD        500.0          -0.18115        0.34821
# 4              NaN          NaN               NaN            NaN
#
#    PASSIVE_2_bf        PASSIVE_2  PASSIVE_3_snr  PASSIVE_3_bf  \
# 0        1714.0  BRT005c10_p_PTD            NaN           NaN
# 1           NaN              NaN            NaN           NaN
# 2           NaN              NaN            NaN           NaN
# 3         411.0  BRT007c09_p_PTD        0.87701         473.0
# 4           NaN              NaN            NaN           NaN
#
#          PASSIVE_3  ACTIVE_4_snr  ACTIVE_4_bf         ACTIVE_4  ACTIVE_4_tf  \
# 0              NaN           NaN          NaN              NaN          NaN
# 1              NaN           NaN          NaN              NaN          NaN
# 2              NaN           NaN          NaN              NaN          NaN
# 3  BRT007c11_p_PTD       0.88194        441.0  BRT007c12_a_PTD        500.0
# 4              NaN           NaN          NaN              NaN          NaN
#
#    ACTIVE_4_tardist  PASSIVE_4_snr  PASSIVE_4_bf PASSIVE_4  ACTIVE_0_snr  \
# 0               NaN            NaN           NaN       NaN           NaN
# 1               NaN            NaN           NaN       NaN           NaN
# 2               NaN            NaN           NaN       NaN           NaN
# 3          -0.18115            NaN           NaN       NaN           NaN
# 4               NaN            NaN           NaN       NaN           NaN
#
#    ACTIVE_0_bf ACTIVE_0  ACTIVE_0_tf  ACTIVE_0_tardist  ACTIVE_5_snr  \
# 0          NaN      NaN          NaN               NaN           NaN
# 1          NaN      NaN          NaN               NaN           NaN
# 2          NaN      NaN          NaN               NaN           NaN
# 3          NaN      NaN          NaN               NaN           NaN
# 4          NaN      NaN          NaN               NaN           NaN
#
#    ACTIVE_5_bf ACTIVE_5  ACTIVE_5_tf  ACTIVE_5_tardist
# 0          NaN      NaN          NaN               NaN
# 1          NaN      NaN          NaN               NaN
# 2          NaN      NaN          NaN               NaN
# 3          NaN      NaN          NaN               NaN
# 4          NaN      NaN          NaN               NaN

# %%
# concat all strf dataframes
d_strf = pd.concat([d_295_strf, d_307_strf, d_313_strf], sort=False)

# %%
d_strf.head()
# Out:
#        cellid  bestsnr  bestbf  PASSIVE_0_snr  PASSIVE_0_bf        PASSIVE_0  \
# 0  btn006a-b1  1.90130    9801       1.901300          9801  btn006a01_p_TOR
# 1  btn009b-b1  0.29041   13337       0.290410         13337  btn009b02_p_TOR
# 2  btn011a-b1  0.66152     639       0.661520           639  btn011a02_p_TOR
# 3  btn011c-b1  0.72878     441       0.728780           441  btn011c01_p_TOR
# 4  btn012c-a1  1.66290   10810       0.058383         24184  btn012c01_p_TOR
#
#    ACTIVE_1_snr  ACTIVE_1_bf         ACTIVE_1  ACTIVE_1_tf  ACTIVE_1_tardist  \
# 0       0.49429       9464.0  btn006a02_a_PTD      10000.0         -0.028999
# 1       0.16060       2858.0  btn009b03_a_PTD      14000.0         -0.069993
# 2       0.38448       7407.0  btn011a03_a_PTD        650.0         -0.024624
# 3       0.55081        457.0  btn011c02_a_PTD        500.0         -0.181150
# 4       1.15170      10438.0  btn012c02_a_PTD       8000.0          0.434290
#
#    PASSIVE_1_snr  PASSIVE_1_bf        PASSIVE_1  ACTIVE_2_snr  ACTIVE_2_bf  \
# 0            NaN           NaN              NaN           NaN          NaN
# 1            NaN           NaN              NaN           NaN          NaN
# 2            NaN           NaN              NaN           NaN          NaN
# 3            NaN           NaN              NaN           NaN          NaN
# 4         1.6016       18277.0  btn012c04_p_PTD        1.6629      10810.0
#
#           ACTIVE_2  ACTIVE_2_tf  ACTIVE_2_tardist  ACTIVE_0_snr  ACTIVE_0_bf  \
# 0              NaN          NaN               NaN           NaN          NaN
# 1              NaN          NaN               NaN           NaN          NaN
# 2              NaN          NaN               NaN           NaN          NaN
# 3              NaN          NaN               NaN           NaN          NaN
# 4  btn012c05_a_PTD      10500.0          0.041977           NaN          NaN
#
#   ACTIVE_0  ACTIVE_0_tf  ACTIVE_0_tardist  ACTIVE_3_snr  ACTIVE_3_bf ACTIVE_3  \
# 0      NaN          NaN               NaN           NaN          NaN      NaN
# 1      NaN          NaN               NaN           NaN          NaN      NaN
# 2      NaN          NaN               NaN           NaN          NaN      NaN
# 3      NaN          NaN               NaN           NaN          NaN      NaN
# 4      NaN          NaN               NaN           NaN          NaN      NaN
#
#    ACTIVE_3_tf  ACTIVE_3_tardist  PASSIVE_2_snr  PASSIVE_2_bf PASSIVE_2  \
# 0          NaN               NaN            NaN           NaN       NaN
# 1          NaN               NaN            NaN           NaN       NaN
# 2          NaN               NaN            NaN           NaN       NaN
# 3          NaN               NaN            NaN           NaN       NaN
# 4          NaN               NaN            NaN           NaN       NaN
#
#    PASSIVE_3_snr  PASSIVE_3_bf PASSIVE_3  ACTIVE_4_snr  ACTIVE_4_bf ACTIVE_4  \
# 0            NaN           NaN       NaN           NaN          NaN      NaN
# 1            NaN           NaN       NaN           NaN          NaN      NaN
# 2            NaN           NaN       NaN           NaN          NaN      NaN
# 3            NaN           NaN       NaN           NaN          NaN      NaN
# 4            NaN           NaN       NaN           NaN          NaN      NaN
#
#    ACTIVE_4_tf  ACTIVE_4_tardist  PASSIVE_4_snr  PASSIVE_4_bf PASSIVE_4  \
# 0          NaN               NaN            NaN           NaN       NaN
# 1          NaN               NaN            NaN           NaN       NaN
# 2          NaN               NaN            NaN           NaN       NaN
# 3          NaN               NaN            NaN           NaN       NaN
# 4          NaN               NaN            NaN           NaN       NaN
#
#    ACTIVE_5_snr  ACTIVE_5_bf ACTIVE_5  ACTIVE_5_tf  ACTIVE_5_tardist
# 0           NaN          NaN      NaN          NaN               NaN
# 1           NaN          NaN      NaN          NaN               NaN
# 2           NaN          NaN      NaN          NaN               NaN
# 3           NaN          NaN      NaN          NaN               NaN
# 4           NaN          NaN      NaN          NaN               NaN

# %%
# merge all into one giant df
df = pd.merge(left=d_all, right=d_strf, how='outer', on='cellid')

# %%
# len(d_295_strf[d_295_strf['ACTIVE_0'].isna()])
# 64 NAN for ACTIVE_0
# 10 not nan for ACTIVE_0  (No pre-passive)

# %%
df.columns
# Out:
# Index(['cellid', 'modelname', 'state_sig', 'state_chan', 'MI', 'isolation',
#        'r', 'r_se', 'd', 'g', 'state_chan_alt', 'experimenter', 'area', 'onBF',
#        'SU', 'animal', 'task', 'R2', 'bestsnr', 'bestbf', 'PASSIVE_0_snr',
#        'PASSIVE_0_bf', 'PASSIVE_0', 'ACTIVE_1_snr', 'ACTIVE_1_bf', 'ACTIVE_1',
#        'ACTIVE_1_tf', 'ACTIVE_1_tardist', 'PASSIVE_1_snr', 'PASSIVE_1_bf',
#        'PASSIVE_1', 'ACTIVE_2_snr', 'ACTIVE_2_bf', 'ACTIVE_2', 'ACTIVE_2_tf',
#        'ACTIVE_2_tardist', 'ACTIVE_0_snr', 'ACTIVE_0_bf', 'ACTIVE_0',
#        'ACTIVE_0_tf', 'ACTIVE_0_tardist', 'ACTIVE_3_snr', 'ACTIVE_3_bf',
#        'ACTIVE_3', 'ACTIVE_3_tf', 'ACTIVE_3_tardist', 'PASSIVE_2_snr',
#        'PASSIVE_2_bf', 'PASSIVE_2', 'PASSIVE_3_snr', 'PASSIVE_3_bf',
#        'PASSIVE_3', 'ACTIVE_4_snr', 'ACTIVE_4_bf', 'ACTIVE_4', 'ACTIVE_4_tf',
#        'ACTIVE_4_tardist', 'PASSIVE_4_snr', 'PASSIVE_4_bf', 'PASSIVE_4',
#        'ACTIVE_5_snr', 'ACTIVE_5_bf', 'ACTIVE_5', 'ACTIVE_5_tf',
#        'ACTIVE_5_tardist'],
#       dtype='object')

# %%
def fix_TBD_onBF(df):
    '''This function takes the monster dataframe and adds True to the column 'onBF' when 'ACTIVE_1_tardist' is
    within 0.5 --> half an octave between unit BF and target frequency in ACTIVE 1'''
    BF_TBD = (df['onBF']=='TBD')
    df.loc[BF_TBD, 'onBF'] = df.loc[BF_TBD, 'ACTIVE_1_tardist'].map(lambda x: abs(x)<=0.5)
    return df

# %%
# check before and after applying the func to make sure it works
df['onBF'].value_counts()
# Out:
# TBD      2558
# True      448
# False     288
# Name: onBF, dtype: int64

# %%
df = fix_TBD_onBF(df)

# %%
df['onBF'].value_counts()
# Out:
# False    1746
# True     1548
# Name: onBF, dtype: int64

# %%
df.head()
# Out:
#          cellid                                          modelname state_sig  \
# 0  BRT039c-24-1  psth.fs20-ld-st.fil0-ref-psthfr.s_stategain.S_...   st.fil0
# 1  BRT039c-24-1  psth.fs20-ld-st.fil0-ref-psthfr.s_stategain.S_...   st.fil0
# 2  BRT039c-24-1  psth.fs20-ld-st.fil0-ref-psthfr.s_stategain.S_...   st.fil0
# 3  BRT039c-24-1  psth.fs20-ld-st.fil0-ref-psthfr.s_stategain.S_...   st.fil0
# 4  BRT039c-24-1  psth.fs20-ld-st.fil0-ref-psthfr.s_stategain.S_...   st.fil0
#
#   state_chan        MI  isolation         r      r_se         d         g  \
# 0   baseline       NaN       95.0  0.527888  0.025994  0.479120  0.987548
# 1   ACTIVE_0  0.000929       95.0  0.527888  0.025994  0.010215  0.030706
# 2   ACTIVE_1  0.007505       95.0  0.527888  0.025994  0.006502 -0.047759
# 3  PASSIVE_1 -0.000139       95.0  0.527888  0.025994  0.001432 -0.065587
# 4   ACTIVE_2 -0.009450       95.0  0.527888  0.025994  0.009505  0.068927
#
#   state_chan_alt experimenter area   onBF    SU animal task        R2  \
# 0       baseline           DS   AC  False  True    BRT  TIN  0.278666
# 1       ACTIVE_0           DS   AC  False  True    BRT  TIN  0.278666
# 2       ACTIVE_1           DS   AC  False  True    BRT  TIN  0.278666
# 3      PASSIVE_1           DS   AC  False  True    BRT  TIN  0.278666
# 4       ACTIVE_2           DS   AC  False  True    BRT  TIN  0.278666
#
#    bestsnr  bestbf  PASSIVE_0_snr  PASSIVE_0_bf          PASSIVE_0  \
# 0  0.66364  8520.0        0.34792        8824.0  BRT039c05_p_PTD.m
# 1  0.66364  8520.0        0.34792        8824.0  BRT039c05_p_PTD.m
# 2  0.66364  8520.0        0.34792        8824.0  BRT039c05_p_PTD.m
# 3  0.66364  8520.0        0.34792        8824.0  BRT039c05_p_PTD.m
# 4  0.66364  8520.0        0.34792        8824.0  BRT039c05_p_PTD.m
#
#    ACTIVE_1_snr  ACTIVE_1_bf           ACTIVE_1  ACTIVE_1_tf  \
# 0       0.40004      15450.0  BRT039c06_a_PTD.m       5000.0
# 1       0.40004      15450.0  BRT039c06_a_PTD.m       5000.0
# 2       0.40004      15450.0  BRT039c06_a_PTD.m       5000.0
# 3       0.40004      15450.0  BRT039c06_a_PTD.m       5000.0
# 4       0.40004      15450.0  BRT039c06_a_PTD.m       5000.0
#
#    ACTIVE_1_tardist  PASSIVE_1_snr  PASSIVE_1_bf       ...         \
# 0           0.76893        0.37762        8824.0       ...
# 1           0.76893        0.37762        8824.0       ...
# 2           0.76893        0.37762        8824.0       ...
# 3           0.76893        0.37762        8824.0       ...
# 4           0.76893        0.37762        8824.0       ...
#
#   ACTIVE_2_tardist  ACTIVE_0_snr  ACTIVE_0_bf           ACTIVE_0  ACTIVE_0_tf  \
# 0          0.76893       0.25217       8520.0  BRT039c04_a_PTD.m       5000.0
# 1          0.76893       0.25217       8520.0  BRT039c04_a_PTD.m       5000.0
# 2          0.76893       0.25217       8520.0  BRT039c04_a_PTD.m       5000.0
# 3          0.76893       0.25217       8520.0  BRT039c04_a_PTD.m       5000.0
# 4          0.76893       0.25217       8520.0  BRT039c04_a_PTD.m       5000.0
#
#    ACTIVE_0_tardist  ACTIVE_3_snr  ACTIVE_3_bf ACTIVE_3  ACTIVE_3_tf  \
# 0           0.76893           NaN          NaN      NaN          NaN
# 1           0.76893           NaN          NaN      NaN          NaN
# 2           0.76893           NaN          NaN      NaN          NaN
# 3           0.76893           NaN          NaN      NaN          NaN
# 4           0.76893           NaN          NaN      NaN          NaN
#
#    ACTIVE_3_tardist  PASSIVE_2_snr  PASSIVE_2_bf          PASSIVE_2  \
# 0               NaN        0.41543        9138.0  BRT039c09_p_PTD.m
# 1               NaN        0.41543        9138.0  BRT039c09_p_PTD.m
# 2               NaN        0.41543        9138.0  BRT039c09_p_PTD.m
# 3               NaN        0.41543        9138.0  BRT039c09_p_PTD.m
# 4               NaN        0.41543        9138.0  BRT039c09_p_PTD.m
#
#    PASSIVE_3_snr  PASSIVE_3_bf  PASSIVE_3  ACTIVE_4_snr ACTIVE_4_bf  ACTIVE_4  \
# 0            NaN           NaN        NaN           NaN         NaN       NaN
# 1            NaN           NaN        NaN           NaN         NaN       NaN
# 2            NaN           NaN        NaN           NaN         NaN       NaN
# 3            NaN           NaN        NaN           NaN         NaN       NaN
# 4            NaN           NaN        NaN           NaN         NaN       NaN
#
#    ACTIVE_4_tf ACTIVE_4_tardist  PASSIVE_4_snr  PASSIVE_4_bf PASSIVE_4  \
# 0          NaN              NaN            NaN           NaN       NaN
# 1          NaN              NaN            NaN           NaN       NaN
# 2          NaN              NaN            NaN           NaN       NaN
# 3          NaN              NaN            NaN           NaN       NaN
# 4          NaN              NaN            NaN           NaN       NaN
#
#    ACTIVE_5_snr  ACTIVE_5_bf  ACTIVE_5  ACTIVE_5_tf ACTIVE_5_tardist
# 0           NaN          NaN       NaN          NaN              NaN
# 1           NaN          NaN       NaN          NaN              NaN
# 2           NaN          NaN       NaN          NaN              NaN
# 3           NaN          NaN       NaN          NaN              NaN
# 4           NaN          NaN       NaN          NaN              NaN
#
# [5 rows x 65 columns]

# %% [markdown]
# ## Comparisons of gain, offset and MI between datasets

# %%
# variables to slice up df 
AC = df['area']=='AC'
IC = df['area']=='IC'
onBF = df['onBF']==True
offBF = df['onBF']==False

df_fil = df[df['state_sig']=='st.fil']
active1 = df_fil['state_chan']=='ACTIVE_1'
passive1 = df_fil['state_chan']=='PASSIVE_1'

# %%
def plotme(df, x_col, y_col, title=None, savefigure=False):
    #ax = sns.violinplot(x=x_col, y=y_col, data=df)
    ax = plt.figure(num=None, figsize=(6,4), dpi=80, facecolor='w', edgecolor='k')
    ax = sns.boxplot(x=x_col, y=y_col, data=df)
    ax =sns.swarmplot(x=x_col, y=y_col, data=df, color='black')
    plt.axhline(color='k', linestyle='--', linewidth=0.5)
    plt.ylabel(y_col)
    #ax.set_aspect(aspect=0.5)
    if title:
        plt.title(title)
    if savefigure:
        plt.savefig(title+x_col+y_col+'.pdf')

# %%
plotme(df[AC & active1], 'animal', 'g', title='AC_P0A1_gain_per_animal')

# %%
plotme(df[AC & active1], 'task', 'g', title='AC_P0A1_gain_per_task')

# %%
plotme(df[AC & active1], 'task', 'd', title='AC_P0A1_offset_per_task')

# %%
plotme(df[AC & active1], 'task', 'MI', title='AC_P0A1_MI_per_task')

# %%
plotme(df[AC & onBF & active1], 'task', 'g', title='AC_onBF_P0A1_gain_per_task')

# %%
plotme(df[AC & onBF & active1], 'task', 'MI', title='AC_onBF_P0A1_MI_per_task')

# %%
plotme(df[AC & offBF & active1], 'task', 'g', title='AC_offBF_P0A1_gain_per_task')

# %%
plotme(df[AC & offBF & active1], 'task', 'd', title='AC_offBF_P0A1_offset_per_task')

# %%
plotme(df[AC & offBF & active1], 'task', 'MI', title='AC_offBF_P0A1_MI_per_task')

# %%
plotme(df[IC & active1], 'animal', 'g', title='IC_P0A1_gain_per_animal')

# %%
plotme(df[IC & passive1], 'animal', 'g', title='IC_P0P1_gain_per_animal')

# %%
plotme(df[IC & active1], 'experimenter', 'g', title='IC_P0A1_gain_per_task')

# %%
plotme(df[IC & active1], 'task', 'MI', title='IC_onBF_P0A1_MI_per_task')

# %%
plotme(df[IC & onBF & active1], 'task', 'g', title='IC_onBF_P0A1_gain_per_task')

# %%
plotme(df[IC & onBF & active1], 'task', 'MI', title='IC_onBF_P0A1_MI_per_task')

# %%
plotme(df[IC & offBF & active1], 'task', 'g', title='IC_offBF_P0A1_gain_per_task')

# %%
plotme(df[IC & offBF & active1], 'task', 'MI', title='IC_offBF_P0A1_MI_per_task')
